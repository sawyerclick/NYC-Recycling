# %% [markdown]
# # For High Society, Low Recycling: the notebook
# By [Sawyer Click](https://sawyerclick.github.io)
#
#
#
# ### Table of Contents
# - [__Monthly Tonnage Reports__](#monthly-tonnage-reports)
#
# #### About this project
# This project looks at the recycling habits of New York City community districts over the last few decades. More specifically, I'm drilling in to Monthly Tonnage Reports and Census data to note how a district's demographics, such as poverty rate, median household income, and race, play into these habits.
#
# #### Data notes
# Monthly Tonnage Reports track residences and institutions (not businesses) serviced by New York's Department of Sanitation

# %%
import pandas as pd
import numpy as np
import datetime as dt
import json
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
pd.set_option('display.max_colwidth', -1)

# %matplotlib inline
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <a id='monthly-tonnage-reports'>Reading in Monthly Tonnage Reports</a>
#
# The data is compiled from [Monthly Tonnage Reports](https://data.cityofnewyork.us/City-Government/DSNY-Monthly-Tonnage-Data/ebb7-mvp5) from the Department of Sanitation.
#
# Rows are by __month__ and __community-district__, which let's us build a timeline of recycling in New York City's districts

# %%
## here's what our data looks like
reports = pd.read_csv('monthly_tonnage_reports.csv')
reports.head()
# Out:
#        MONTH    BOROUGH  COMMUNITYDISTRICT  REFUSETONSCOLLECTED  \
# 0  1993 / 11  Manhattan  1                  625.2
# 1  1995 / 09  Manhattan  1                  633.1
# 2  1995 / 08  Manhattan  1                  627.5
# 3  2012 / 03  Manhattan  1                  1194.4
# 4  1992 / 03  Manhattan  1                  726.0
#
#    PAPERTONSCOLLECTED  MGPTONSCOLLECTED  RESORGANICSTONS  SCHOOLORGANICTONS  \
# 0  119.4               34.4             NaN              NaN
# 1  117.2               45.8             NaN              NaN
# 2  82.4                35.6             NaN              NaN
# 3  341.6               210.8            NaN              NaN
# 4 NaN                 NaN               NaN              NaN
#
#    LEAVESORGANICTONS  XMASTREETONS  BOROUGH_ID
# 0 NaN                NaN            1
# 1 NaN                NaN            1
# 2 NaN                NaN            1
# 3 NaN                NaN            1
# 4 NaN                NaN            1

# %% [markdown]
# ## We need to run a bit of cleaning to help keep things organized

# %%
## let's fill NaNs with zeroes bc they mean 0 here
reports = reports.fillna(0)

## make datetime, separate the year
reports['datetime'] = pd.to_datetime(reports.MONTH)
reports['year'] = reports.datetime.astype(str).str.extract(r'^(.*)-.*-.*').astype(int)
reports['month'] = reports.datetime.astype(str).str.extract(r'^.*-(.*)-.*').astype(int)

## read back borough ids as strings
reports.BOROUGH_ID = reports.BOROUGH_ID.astype(str) 

# give the boro code by smashing together the borough id and community district number
def get_boro_code(x):
    return x.BOROUGH_ID + "{:02d}".format(x.COMMUNITYDISTRICT)
reports['borough_code'] = reports.apply(get_boro_code, axis=1)

## first we need to cut out 2020 months
## because the year isn't finished yet and we're most interested in years
reports = reports[(reports.year < 2020) & (reports.year > 2008)]

reports.head()
# Out:
#         MONTH    BOROUGH  COMMUNITYDISTRICT  REFUSETONSCOLLECTED  \
# 3   2012 / 03  Manhattan  1                  1194.4
# 9   2012 / 01  Brooklyn   7                  3156.7
# 13  2016 / 11  Brooklyn   7                  3356.9
# 21  2013 / 11  Brooklyn   7                  3179.2
# 23  2010 / 12  Brooklyn   7                  2514.9
#
#     PAPERTONSCOLLECTED  MGPTONSCOLLECTED  RESORGANICSTONS  SCHOOLORGANICTONS  \
# 3   341.6               210.8             0.0              0.0
# 9   436.6               343.4             0.0              0.0
# 13  424.4               380.3             120.1            0.0
# 21  398.7               318.3             57.5             0.0
# 23  367.6               275.5             0.0              0.0
#
#     LEAVESORGANICTONS  XMASTREETONS BOROUGH_ID   datetime  year  month  \
# 3   0.0                0.0           1         2012-03-01  2012  3
# 9   0.0                20.1          3         2012-01-01  2012  1
# 13  2.5                0.0           3         2016-11-01  2016  11
# 21  0.0                0.0           3         2013-11-01  2013  11
# 23  0.0                0.0           3         2010-12-01  2010  12
#
#    borough_code
# 3   101
# 9   307
# 13  307
# 21  307
# 23  307

# %% [markdown]
# ## Checking out refuse emissions from each borough
#
# Remember! Some boroughs are more populous than others, cover a larger land mass, or have larger community districts. All of these mess with the raw numbers. This is mostly to give us an idea of what we're working with

# %%
sns.relplot(data=reports,\
             x='year',\
             y='REFUSETONSCOLLECTED',\
             col='BOROUGH',\
             kind='line'\
            )

# %% [markdown]
# ## Some cool math to get percentages!

# %%
reports.head()
# Out:
#         MONTH    BOROUGH  COMMUNITYDISTRICT  REFUSETONSCOLLECTED  \
# 3   2012 / 03  Manhattan  1                  1194.4
# 9   2012 / 01  Brooklyn   7                  3156.7
# 13  2016 / 11  Brooklyn   7                  3356.9
# 21  2013 / 11  Brooklyn   7                  3179.2
# 23  2010 / 12  Brooklyn   7                  2514.9
#
#     PAPERTONSCOLLECTED  MGPTONSCOLLECTED  RESORGANICSTONS  SCHOOLORGANICTONS  \
# 3   341.6               210.8             0.0              0.0
# 9   436.6               343.4             0.0              0.0
# 13  424.4               380.3             120.1            0.0
# 21  398.7               318.3             57.5             0.0
# 23  367.6               275.5             0.0              0.0
#
#     LEAVESORGANICTONS  XMASTREETONS BOROUGH_ID   datetime  year  month  \
# 3   0.0                0.0           1         2012-03-01  2012  3
# 9   0.0                20.1          3         2012-01-01  2012  1
# 13  2.5                0.0           3         2016-11-01  2016  11
# 21  0.0                0.0           3         2013-11-01  2013  11
# 23  0.0                0.0           3         2010-12-01  2010  12
#
#    borough_code
# 3   101
# 9   307
# 13  307
# 21  307
# 23  307

# %%
## these are the basic recycled materials. 
## Paper, plastics + metals, and organics
reports['total_recycled'] = reports.PAPERTONSCOLLECTED\
                            + reports.MGPTONSCOLLECTED\
                            + reports.RESORGANICSTONS

## we can calculate total waste by adding these up
## refuse refers to non-recycled materials
reports['total_waste'] = reports.total_recycled\
                        + reports.REFUSETONSCOLLECTED

## now we can calculate percents to help put everyone on the same level!!
reports['percent_recycled'] = reports['total_recycled'] / reports['total_waste'] * 100

# %% [markdown]
# ## Sorting totals by year to get diversion

# %%
racingChart = reports.groupby('year').total_recycled.sum().reset_index(name='Recycled')

racingChart['Waste'] = reports.groupby('year').REFUSETONSCOLLECTED.sum().reset_index(name='Waste').Waste
racingChart['Total'] = reports.groupby('year').total_waste.sum().reset_index(name='Total').Total

racingChart.to_csv('year_raw_waste_and_recycled.csv', index=False)
racingChart['Diversion'] = racingChart['Recycled'] / racingChart['Waste'] * 100
racingChart
# Out:
#     year  Recycled      Waste      Total  Diversion
# 0   2009  542333.4  2591531.2  3133864.6  20.927141
# 1   2010  520237.5  2534393.8  3054631.3  20.527098
# 2   2011  521395.4  2663828.9  3185224.3  19.573157
# 3   2012  494795.4  2586978.9  3081774.3  19.126379
# 4   2013  504466.2  2553356.8  3057823.0  19.756980
# 5   2014  528324.9  2528444.5  3056769.4  20.895254
# 6   2015  552411.1  2498990.8  3051401.9  22.105367
# 7   2016  585830.0  2503022.1  3088852.1  23.404907
# 8   2017  600721.5  2504617.2  3105338.7  23.984563
# 9   2018  628501.1  2528028.2  3156529.3  24.861317
# 10  2019  631494.0  2513445.0  3144939.0  25.124640

# %%
## what's been the change in the amount of refuse?
## this tells us if there's been a change in waste and consumer habits
(racingChart['Waste'][10] - racingChart['Waste'][0]) / racingChart['Waste'][0] * 100
# Out:
# -3.0131298438543785

# %%
reports.groupby('year').total_recycled.sum() / reports.groupby('year').total_waste.sum() * 100
# Out:
# year
# 2009    17.305579
# 2010    17.031106
# 2011    16.369189
# 2012    16.055537
# 2013    16.497561
# 2014    17.283767
# 2015    18.103518
# 2016    18.965945
# 2017    19.344798
# 2018    19.911144
# 2019    20.079690
# dtype: float64

# %% [markdown]
# ## Sorting so we can make a ridgeplot

# %%
print(reports.groupby('BOROUGH').percent_recycled.median().sort_values())

def get_order(x):
    if x.BOROUGH == 'Bronx':
        return 1
    elif x.BOROUGH == 'Brooklyn':
        return 2
    elif x.BOROUGH == 'Queens':
        return 3
    elif x.BOROUGH == 'Staten Island':
        return 4
    elif x.BOROUGH == 'Manhattan':
        return 5
    
reports['mean_order'] = reports.apply(get_order, axis=1)

reports = reports.sort_values('mean_order')
# Out:
# BOROUGH
# Bronx            12.584109
# Brooklyn         15.587882
# Queens           18.636092
# Staten Island    20.144908
# Manhattan        23.607803
# Name: percent_recycled, dtype: float64

# %%
# https://seaborn.pydata.org/examples/kde_ridgeplot.html

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)}, font_scale = 1.5)

# Initialize the FacetGrid object
pal = sns.color_palette("ch:2,r=.2,l=.6")
g = sns.FacetGrid(reports, row="BOROUGH", hue="BOROUGH", aspect=15, height=1, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "percent_recycled", clip_on=False, shade=True, alpha=.9, lw=1.5, bw=.2)
g.map(sns.kdeplot, "percent_recycled", clip_on=False, color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2, clip_on=False)

# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .1, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)
    
g.map(label, "percent_recycled")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.7)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set_ylabels('')    
g.set_xlabels('')
g.set(yticks=[])
g.set(xticks=[0,5,10,15,20,25,30,35,40])
# g.set(xticklabe)
g.despine(bottom=True, left=True)

# plt.savefig('')

# %% [markdown]
# ## percent difference calculator

# %%
## crude but a way to get unique borough codes matched
matchDF = reports[reports.year == 2019][['BOROUGH', 'borough_code', 'total_waste']].groupby(['BOROUGH','borough_code']).total_waste.sum().reset_index()

# %%
## 2019 community district recycling rates
bydist_2019 = (reports[reports['year'] == 2019].groupby('borough_code').total_recycled.sum()\
 / reports[reports['year'] == 2019].groupby('borough_code').total_waste.sum()\
 * 100).reset_index(name='pct_recyc_2019')

## 2009 community district recycling rates
bydist_2009 = (reports[reports['year'] == 2009].groupby('borough_code').total_recycled.sum()\
 / reports[reports['year'] == 2009].groupby('borough_code').total_waste.sum()\
 * 100).reset_index(name='pct_recyc_2009')

bydist = pd.merge(bydist_2019,bydist_2009, on='borough_code')
bydist.columns = ['borough_code','pct_recyc_2019','pct_recyc_2009']
bydist['pct_change'] = (bydist['pct_recyc_2019'] / bydist['pct_recyc_2009'] - 1) * 100

bydist['pct_point_change'] = bydist['pct_recyc_2019'] - bydist['pct_recyc_2009']

## adding comparitive raw data
## community district recycling, waste and refuse raw
bydist['raw_recyc2019'] = reports[reports['year'] == 2019].groupby('borough_code').total_recycled.sum().reset_index(name='total_recyc').total_recyc
bydist['raw_recyc2009'] = reports[reports['year'] == 2009].groupby('borough_code').total_recycled.sum().reset_index(name='total_recyc').total_recyc

bydist['raw_refuse2019'] = reports[reports['year'] == 2019].groupby('borough_code').REFUSETONSCOLLECTED.sum().reset_index(name='total_refuse').total_refuse
bydist['raw_refuse2009'] = reports[reports['year'] == 2009].groupby('borough_code').REFUSETONSCOLLECTED.sum().reset_index(name='total_refuse').total_refuse

## this is technically the ones above added together
bydist['raw_waste2019'] = reports[reports['year'] == 2019].groupby('borough_code').total_waste.sum().reset_index(name='total_waste').total_waste
bydist['raw_waste2009'] = reports[reports['year'] == 2009].groupby('borough_code').total_waste.sum().reset_index(name='total_waste').total_waste

## attach borough names
bydist = pd.merge(matchDF, bydist, on='borough_code')

## preview of our master set
bydist.head()
# Out:
#   BOROUGH borough_code  total_waste  pct_recyc_2019  pct_recyc_2009  \
# 0  Bronx   201          26846.6      12.366184       7.870703
# 1  Bronx   202          21047.1      14.884711       8.893841
# 2  Bronx   203          26854.5      14.363328       7.740898
# 3  Bronx   204          55008.7      13.445328       7.735052
# 4  Bronx   205          47309.5      13.256323       10.276473
#
#    pct_change  pct_point_change  raw_recyc2019  raw_recyc2009  raw_refuse2019  \
# 0  57.116635   4.495481          3319.9         1970.1         23526.7
# 1  67.359754   5.990870          3132.8         1987.4         17914.3
# 2  85.551197   6.622431          3857.2         1843.1         22997.3
# 3  73.823361   5.710276          7396.1         4524.0         47612.6
# 4  28.996815   2.979850          6271.5         5025.0         41038.0
#
#    raw_refuse2009  raw_waste2019  raw_waste2009
# 0  23060.7         26846.6        25030.8
# 1  20358.4         21047.1        22345.8
# 2  21966.8         26854.5        23809.9
# 3  53963.0         55008.7        58487.0
# 4  43873.1         47309.5        48898.1

# %%
## is anyone producing more waste?
## this is what has killed zero waste in several cities

## new - old tells us who is recycling less. > 0 means there's more waste
moreWaste = bydist[bydist['raw_refuse2019'] - bydist['raw_refuse2009'] > 0]

print(f'There are {moreWaste.shape[0]} districts producing more waste out of the 59 total.')

moreWaste.BOROUGH.value_counts()
# Out:
# There are 20 districts producing more waste out of the 59 total.
# Brooklyn     8
# Queens       6
# Manhattan    4
# Bronx        2
# Name: BOROUGH, dtype: int64

# %% [markdown]
# # Reading and cleaning demographic data
#
# These are all from the census. I used social explorer

# %%
## there are a ton of columns so we're just going to use these
columns =[
    'borocd',
    'acres',
    'cd_full_title',
    'fp_100_rent_burden',
    'neighborhoods',
    'pct_bach_deg',
    'pct_foreign_born',
    'poverty_rate',
    'under18_rate'
]

demo_ish = pd.read_csv('demographic_data/cd_demographics.csv', usecols=columns)
demo_ish.borocd = demo_ish.borocd.astype(str)

demo_ish.head()
# Out:
#     acres borocd                   cd_full_title  fp_100_rent_burden  \
# 0  976.3   101    Manhattan Community District 1  0.353232
# 1  865.9   102    Manhattan Community District 2  0.353232
# 2  1076.9  103    Manhattan Community District 3  0.463410
# 3  1131.6  104    Manhattan Community District 4  0.423210
# 4  1005.4  105    Manhattan Community District 5  0.000000
#
#                                                                                                                                      neighborhoods  \
# 0  Battery Park City, Civic Center, Ellis Island, Governors Island, Liberty Island, South Street Seaport, Tribeca, Wall Street, World Trade Center
# 1  Greenwich Village, Hudson Square, Little Italy, NoHo, SoHo, South Village, West Village
# 2  Chinatown, East Village, Lower East Side, NoHo, Two Bridges
# 3  Chelsea, Clinton, Hudson Yards
# 4  Flatiron, Gramercy Park, Herald Square, Midtown, Midtown South, Murray Hill, Times Square, Union Square
#
#    pct_bach_deg  pct_foreign_born  poverty_rate  under18_rate
# 0  82.3          23.9              8.8           12.8
# 1  82.3          23.9              8.8           12.8
# 2  43.0          34.9              19.3          11.7
# 3  74.4          29.4              11.3          8.2
# 4  74.4          29.4              11.3          8.2

# %%
## Fips here === community district
income = pd.read_csv('demographic_data/median_income.csv', skiprows=4, dtype={'Fips': str})

## stripping to most recent data | 2017
## and trimming it down to just the columns we need
income = income[(income.TimeFrame == 2017) & (income['Household Type'] == 'All Households')][['Data','Fips']].rename(columns={'Data':'income', 'Fips':'borocd'})

income.head()
# Out:
#         income borocd
# 3120  144878.0  101
# 3121  144878.0  102
# 3122  39584.0   103
# 3123  101981.0  104
# 3124  101981.0  105

# %%
## Fips here === community district
population = pd.read_csv('demographic_data/total_population.csv', skiprows=4, dtype={'Fips': str})

## stripping to most recent data | 2017
## and trimming it down to just the columns we need
population = population[(population.TimeFrame == 2017) & (population['Fips'].str.contains(r'\w\w\w\w+') == False)][['Data','Fips', 'Location']].rename(columns={'Data':'population', 'Fips':'borocd'})

population.head()
# Out:
#        population borocd                   Location
# 780  60165.46615   101    Battery Park/Tribeca
# 781  88816.53385   102    Greenwich Village
# 782  160490.00000  103    Lower East Side
# 783  101603.53526  104    Chelsea/Clinton
# 784  50851.46474   105    Midtown Business District

# %%
income_and_pop = pd.merge(population, income, on='borocd')

# %%
## now we have a solid demographic dataset
demo = pd.merge(demo_ish, income_and_pop, on='borocd')
demo.head()
# Out:
#     acres borocd                   cd_full_title  fp_100_rent_burden  \
# 0  976.3   101    Manhattan Community District 1  0.353232
# 1  865.9   102    Manhattan Community District 2  0.353232
# 2  1076.9  103    Manhattan Community District 3  0.463410
# 3  1131.6  104    Manhattan Community District 4  0.423210
# 4  1005.4  105    Manhattan Community District 5  0.000000
#
#                                                                                                                                      neighborhoods  \
# 0  Battery Park City, Civic Center, Ellis Island, Governors Island, Liberty Island, South Street Seaport, Tribeca, Wall Street, World Trade Center
# 1  Greenwich Village, Hudson Square, Little Italy, NoHo, SoHo, South Village, West Village
# 2  Chinatown, East Village, Lower East Side, NoHo, Two Bridges
# 3  Chelsea, Clinton, Hudson Yards
# 4  Flatiron, Gramercy Park, Herald Square, Midtown, Midtown South, Murray Hill, Times Square, Union Square
#
#    pct_bach_deg  pct_foreign_born  poverty_rate  under18_rate    population  \
# 0  82.3          23.9              8.8           12.8          60165.46615
# 1  82.3          23.9              8.8           12.8          88816.53385
# 2  43.0          34.9              19.3          11.7          160490.00000
# 3  74.4          29.4              11.3          8.2           101603.53526
# 4  74.4          29.4              11.3          8.2           50851.46474
#
#                     Location    income
# 0  Battery Park/Tribeca       144878.0
# 1  Greenwich Village          144878.0
# 2  Lower East Side            39584.0
# 3  Chelsea/Clinton            101981.0
# 4  Midtown Business District  101981.0

# %% [markdown]
# # Merging recycling and demographic data

# %%
df = pd.merge(bydist, demo, left_on='borough_code',right_on='borocd')

df.head()
# Out:
#   BOROUGH borough_code  total_waste  pct_recyc_2019  pct_recyc_2009  \
# 0  Bronx   201          26846.6      12.366184       7.870703
# 1  Bronx   202          21047.1      14.884711       8.893841
# 2  Bronx   203          26854.5      14.363328       7.740898
# 3  Bronx   204          55008.7      13.445328       7.735052
# 4  Bronx   205          47309.5      13.256323       10.276473
#
#    pct_change  pct_point_change  raw_recyc2019  raw_recyc2009  raw_refuse2019  \
# 0  57.116635   4.495481          3319.9         1970.1         23526.7
# 1  67.359754   5.990870          3132.8         1987.4         17914.3
# 2  85.551197   6.622431          3857.2         1843.1         22997.3
# 3  73.823361   5.710276          7396.1         4524.0         47612.6
# 4  28.996815   2.979850          6271.5         5025.0         41038.0
#
#    ...               cd_full_title  fp_100_rent_burden  \
# 0  ...  Bronx Community District 1  0.580417
# 1  ...  Bronx Community District 2  0.580417
# 2  ...  Bronx Community District 3  0.530688
# 3  ...  Bronx Community District 4  0.617179
# 4  ...  Bronx Community District 5  0.650425
#
#                                                                           neighborhoods  \
# 0  Melrose, Mott Haven, Port Morris
# 1  Hunts Point, Longwood
# 2  Claremont, Crotona Park East, Melrose, Morrisania
# 3  Concourse, Concourse Village, East Concourse, Highbridge, Mount Eden, West Concourse
# 4  Fordham, Morris Heights, Mount Hope, University Heights
#
#    pct_bach_deg pct_foreign_born poverty_rate  under18_rate    population  \
# 0  10.3          29.5             31.0         28.4          99526.21296
# 1  10.3          29.5             31.0         28.4          56830.78704
# 2  13.3          31.4             30.3         28.9          92015.20058
# 3  15.0          43.1             32.4         27.5          149710.00000
# 4  13.1          43.4             35.6         28.7          148339.00000
#
#                Location   income
# 0  Mott Haven            20966.0
# 1  Hunts Point           20966.0
# 2  Morrisania            25972.0
# 3  Concourse/Highbridge  30900.0
# 4  University Heights    30166.0
#
# [5 rows x 25 columns]

# %%
## sorting from greatest change to least and given them places
df = df.sort_values('pct_point_change', ascending=False).reset_index(drop=True).reset_index().rename(columns={'index':'place'})

# %%
## send to a csv
df.to_csv('data.csv', index=False)

## take this to QGIS for a spatial join with community-districts.geojson
## export as data.geojson
## use mapshaper to make it data.json as topojson

# %%
df
# Out:
#     place        BOROUGH borough_code  total_waste  pct_recyc_2019  \
# 0   0      Bronx          203          26854.5      14.363328
# 1   1      Bronx          212          58129.9      23.501159
# 2   2      Brooklyn       304          44156.0      17.424812
# 3   3      Manhattan      110          38520.6      16.651350
# 4   4      Queens         409          59876.0      23.135146
# 5   5      Bronx          202          21047.1      14.884711
# 6   6      Manhattan      109          33324.3      20.461645
# 7   7      Bronx          208          36618.6      24.951254
# 8   8      Bronx          204          55008.7      13.445328
# 9   9      Bronx          210          39341.0      24.657482
# 10  10     Brooklyn       303          57457.0      15.553718
# 11  11     Queens         413          79697.3      22.833898
# 12  12     Bronx          207          52754.6      16.651249
# 13  13     Bronx          206          30783.8      13.906340
# 14  14     Bronx          201          26846.6      12.366184
# 15  15     Queens         401          61887.9      23.853774
# 16  16     Brooklyn       308          38942.6      17.785664
# 17  17     Brooklyn       306          38554.2      34.198609
# 18  18     Brooklyn       302          41935.1      28.599669
# 19  19     Queens         411          46188.1      26.755160
# 20  20     Queens         402          46080.7      23.308240
# 21  21     Manhattan      112          68704.2      17.429357
# 22  22     Brooklyn       313          29408.1      17.743071
# 23  23     Staten Island  501          78704.4      22.555029
# 24  24     Bronx          209          51752.7      13.021929
# 25  25     Manhattan      102          32417.4      29.895982
# 26  26     Manhattan      107          80343.2      29.146960
# 27  27     Queens         414          42242.7      17.227355
# 28  28     Brooklyn       309          42066.8      14.552331
# 29  29     Bronx          211          44223.7      19.657559
# 30  30     Queens         405          74135.8      24.170913
# 31  31     Manhattan      111          32574.5      15.108751
# 32  32     Bronx          205          47309.5      13.256323
# 33  33     Brooklyn       301          78209.5      18.144599
# 34  34     Queens         404          56669.5      15.776211
# 35  35     Brooklyn       307          49091.5      21.675443
# 36  36     Brooklyn       316          28931.0      12.324496
# 37  37     Manhattan      108          86173.2      28.341178
# 38  38     Queens         407          95659.2      20.982509
# 39  39     Queens         412          96778.5      16.222301
# 40  40     Brooklyn       310          50784.0      24.131222
# 41  41     Manhattan      105          21476.0      26.956603
# 42  42     Brooklyn       314          66724.4      15.603288
# 43  43     Queens         408          54430.7      20.689060
# 44  44     Queens         410          56112.8      19.845383
# 45  45     Manhattan      104          39757.1      28.738766
# 46  46     Brooklyn       317          61516.8      14.577969
# 47  47     Brooklyn       305          63179.5      12.643500
# 48  48     Queens         406          42593.7      21.619160
# 49  49     Manhattan      103          43502.8      17.892871
# 50  50     Brooklyn       312          85452.5      15.812293
# 48  55.7          50.6              15.1         17.7         118922.00000
# 49  43.0          34.9              19.3         11.7         160490.00000
# 50  28.7          29.1              27.2         36.3         146556.00000
# 51  20.1          59.8              24.0         22.1         170222.00000
# 52  39.9          49.1              18.6         22.1         171030.00000
# 53  29.5          55.8              22.5         20.9         205850.00000
# 54  32.7          28.0              14.9         21.1         143766.00000
# 55  31.1          40.2              14.6         22.9         215637.00000
# 56  33.4          15.6              12.3         21.5         159060.00000
# 57  82.3          23.9              8.8          12.8         60165.46615
# 58  79.4          22.3              9.8          8.7          149674.00000
#
#                      Location    income
# 0   Morrisania                 25972.0
# 1   Williamsbridge             58773.0
# 2   Bushwick                   50656.0
# 3   Central Harlem             49059.0
# 4   Woodhaven                  69916.0
# 5   Hunts Point                20966.0
# 6   Manhattanville             50048.0
# 7   Riverdale                  53986.0
# 8   Concourse/Highbridge       30900.0
# 9   Throgs Neck                59522.0
# 10  Bedford Stuyvesant         51907.0
# 11  Queens Village             85857.0
# 12  Bedford Park               35355.0
# 13  East Tremont               25972.0
# 14  Mott Haven                 20966.0
# 15  Astoria                    66382.0
# 16  Crown Heights North        60107.0
# 17  Park Slope                 134804.0
# 18  Fort Greene/Brooklyn Hts   92562.0
# 19  Bayside                    70155.0
# 20  Sunnyside/Woodside         67359.0
# 21  Washington Heights         56382.0
# 22  Coney Island               36118.0
# 23  St. George                 62870.0
# 24  Unionport/Soundview        40005.0
# 25  Greenwich Village          144878.0
# 26  Upper West Side            123894.0
# 27  The Rockaways              54012.0
# 28  Crown Heights South        51072.0
# 29  Pelham Parkway             48018.0
# 30  Ridgewood/Glendale         71234.0
# 31  East Harlem                36770.0
# 32  University Heights         30166.0
# 33  Williamsburg/Greenpoint    76608.0
# 34  Elmhurst/Corona            51992.0
# 35  Sunset Park                56787.0
# 36  Brownsville                20254.0
# 37  Upper East Side            131348.0
# 38  Flushing                   51284.0
# 39  Jamaica/St. Albans         61670.0
# 40  Bay Ridge                  68679.0
# 41  Midtown Business District  101981.0
# 42  Flatbush/Midwood           56599.0
# 43  Fresh Meadows/Briarwood    64005.0
# 44  Howard Beach               73891.0
# 45  Chelsea/Clinton            101981.0
# 46  East Flatbush              49349.0
# 47  East New York              36786.0
# 48  Rego Park/Forest Hills     75447.0
# 49  Lower East Side            39584.0
# 50  Borough Park               45364.0
# 51  Jackson Heights            56601.0
# 52  Sheepshead Bay             61274.0
# 53  Bensonhurst                53493.0
# 54  South Beach                81487.0
# 55  Canarsie                   76647.0
# 56  Tottenville                96796.0
# 57  Battery Park/Tribeca       144878.0
# 58  Murray Hill/Stuyvesant     112383.0
#
# [59 rows x 26 columns]

# %%
lines = (reports.groupby(['borough_code', 'year']).total_recycled.sum()\
 / reports.groupby(['borough_code', 'year']).total_waste.sum()\
 * 100).reset_index(name='diversion')

lines.to_csv('diversions.csv', index=False)
lines
# Out:
#     borough_code  year  diversion
# 0    101          2009  34.454363
# 1    101          2010  33.174629
# 2    101          2011  32.023300
# 3    101          2012  29.611664
# 4    101          2013  29.339790
# 5    101          2014  29.878229
# 6    101          2015  31.158099
# 7    101          2016  31.807288
# 8    101          2017  31.072020
# 9    101          2018  31.851910
# 10   101          2019  33.345285
# 11   102          2009  26.366071
# 12   102          2010  26.416018
# 13   102          2011  25.016413
# 14   102          2012  24.139577
# 15   102          2013  24.757210
# 16   102          2014  25.900029
# 17   102          2015  26.996773
# 18   102          2016  28.147262
# 19   102          2017  28.034801
# 20   102          2018  28.836554
# 21   102          2019  29.895982
# 22   103          2009  17.310121
# 23   103          2010  16.924338
# 24   103          2011  15.813323
# 25   103          2012  15.232066
# 26   103          2013  15.754754
# 27   103          2014  16.391038
# 28   103          2015  17.589119
# 29   103          2016  18.332925
# ..   ...           ...        ...
# 619  501          2012  17.694585
# 620  501          2013  19.049170
# 621  501          2014  19.974333
# 622  501          2015  20.796953
# 623  501          2016  21.742439
# 624  501          2017  22.021778
# 625  501          2018  22.402209
# 626  501          2019  22.555029
# 627  502          2009  20.490967
# 628  502          2010  20.109420
# 629  502          2011  19.469183
# 630  502          2012  18.587178
# 631  502          2013  19.285808
# 632  502          2014  20.043844
# 633  502          2015  20.272090
# 634  502          2016  20.799617
# 635  502          2017  20.637919
# 636  502          2018  20.314585
# 637  502          2019  20.230998
# 638  503          2009  21.271058
# 639  503          2010  20.766145
# 640  503          2011  20.120777
# 641  503          2012  19.433957
# 642  503          2013  20.119428
# 643  503          2014  20.528816
# 644  503          2015  20.391849
# 645  503          2016  20.957796
# 646  503          2017  20.702097
# 647  503          2018  20.572007
# 648  503          2019  20.588164
#
# [649 rows x 3 columns]

# %% [markdown]
# # Analysis

# %%
## What's the city's median income?
median_income = df.income.median()

# %% [markdown]
# ## Income histogram by community district

# %%
# https://seaborn.pydata.org/examples/kde_ridgeplot.html

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)}, font_scale = 1.5)

# Initialize the FacetGrid object
pal = sns.color_palette("ch:2,r=.2,l=.5")
g = sns.FacetGrid(df, row="BOROUGH", hue="BOROUGH", aspect=10, height=1, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "income", clip_on=False, shade=True, alpha=.9, lw=1.5, bw=.2)
# g.map(sns.kdeplot, "income", clip_on=False, color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2, clip_on=False)

# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .1, label, fontweight="bold", color='#44745C',
            ha="right", va="center", transform=ax.transAxes, alpha=.6)
    
g.map(label, "income")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.7)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set_ylabels('')    
g.set_xlabels('')
g.set(yticks=[])
# g.set(xticks=[0,5,10,15,20,25,30,35,40])
# g.set(xticklabe)
g.despine(bottom=True, left=True)

# plt.savefig('')

# %% [markdown]
# ### How rich are those recycling less?
#
# FINDINGS:
# - All five of the districts that are recycling a lower percentage of their waste have an income incredibly above the city's median of about $57k

# %%
df[df.pct_point_change < 0][['BOROUGH','borough_code','income']]
# Out:
#           BOROUGH borough_code    income
# 54  Staten Island  502          81487.0
# 55  Brooklyn       318          76647.0
# 56  Staten Island  503          96796.0
# 57  Manhattan      101          144878.0
# 58  Manhattan      106          112383.0

# %%
## this shows the percentage change, not percentage point change
## the idea is I want to see how significant of a shift the change was, not necessarily the raw change
g = sns.scatterplot(data=df, x='income', y='pct_change', hue='BOROUGH')
g.legend(loc='right', bbox_to_anchor=(1.5, 0.5), ncol=1, facecolor='w')
g.vlines(median_income, -10, 100, color='goldenrod', alpha=.4)
g.hlines(0,0,140000, color='gray', alpha=.4)
plt.text(165000,-10,'Median income', color='goldenrod')
print('Poorer districts made more significant gains')
# Out:
# Poorer districts made more significant gains

# %%
## this shows the percentage change, not percentage point change
## the idea is I want to see how significant of a shift the change was, not necessarily the raw change
g = sns.scatterplot(data=df, x='income', y='pct_recyc_2019', hue='BOROUGH')
g.legend(loc='right', bbox_to_anchor=(1.5, 0.5), ncol=1, facecolor='w')
# g.vlines(median_income, -10, 100, color='goldenrod', alpha=.4)
# g.hlines(0,0,140000, color='gray', alpha=.4)
# plt.text(165000,-10,'Median income', color='goldenrod')
print('Poorer districts made more significant gains')
# Out:
# Poorer districts made more significant gains

# %%
## The average person in the city is resposible for 
# 364,725 pounds of waste sent to a landfill, incinerator or the ocean
(df.raw_waste2019.sum() * 1000000) / df.population.sum()
# Out:
# 364725.16237252933

# %%
df[((df.raw_refuse2009 - df.raw_refuse2019) < 0) & (df.income > median_income)][['BOROUGH','borough_code','raw_refuse2019', 'raw_refuse2009', 'income', 'pct_point_change']]
# Out:
#       BOROUGH borough_code  raw_refuse2019  raw_refuse2009    income  \
# 18  Brooklyn   302          29941.8         25913.4         92562.0
# 20  Queens     402          35340.1         32472.7         67359.0
# 33  Brooklyn   301          64018.7         53459.1         76608.0
# 39  Queens     412          81078.8         79745.1         61670.0
# 43  Queens     408          43169.5         42020.8         64005.0
# 44  Queens     410          44977.0         44462.9         73891.0
# 45  Manhattan  104          28331.4         25160.8         101981.0
# 52  Brooklyn   315          53355.0         52977.6         61274.0
# 55  Brooklyn   318          65818.4         64147.4         76647.0
# 57  Manhattan  101          16545.7         13451.8         144878.0
#
#     pct_point_change
# 18  3.955169
# 20  3.883460
# 33  2.814174
# 39  2.146558
# 43  1.612985
# 44  1.467025
# 45  1.375338
# 52  0.456551
# 55 -0.402186
# 57 -1.109078

# %%
df[df.income < median_income][['BOROUGH','borough_code','pct_point_change', 'place']].shape[0]
# Out:
# 29

# %%
df.sort_values('pct_point_change')[['BOROUGH','borough_code','pct_point_change', 'raw_waste2019','raw_waste2009', 'raw_recyc2019','raw_recyc2009']].head()
# Out:
#           BOROUGH borough_code  pct_point_change  raw_waste2019  \
# 58  Manhattan      106         -1.407075          46916.1
# 57  Manhattan      101         -1.109078          24823.0
# 56  Staten Island  503         -0.682895          86217.5
# 55  Brooklyn       318         -0.402186          79701.1
# 54  Staten Island  502         -0.259969          63637.0
#
#     raw_waste2009  raw_recyc2019  raw_recyc2009
# 58  50593.9        12533.4        14227.8
# 57  20522.8        8277.3         7071.0
# 56  88949.5        17750.6        18920.5
# 55  78057.8        13882.7        13910.4
# 54  65646.0        12874.4        13451.5

# %%
df.sort_values('income', ascending=False)[['BOROUGH','borough_code','income','pct_point_change']].head(10)
# Out:
#           BOROUGH borough_code    income  pct_point_change
# 25  Manhattan      102          144878.0  3.529911
# 57  Manhattan      101          144878.0 -1.109078
# 17  Brooklyn       306          134804.0  4.069437
# 37  Manhattan      108          131348.0  2.426845
# 26  Manhattan      107          123894.0  3.501982
# 58  Manhattan      106          112383.0 -1.407075
# 45  Manhattan      104          101981.0  1.375338
# 41  Manhattan      105          101981.0  1.888399
# 56  Staten Island  503          96796.0  -0.682895
# 18  Brooklyn       302          92562.0   3.955169

# %%
df[df.pct_point_change < 0][['place','BOROUGH','borough_code','income','neighborhoods']]
# Out:
#     place        BOROUGH borough_code    income  \
# 54  54     Staten Island  502          81487.0
# 55  55     Brooklyn       318          76647.0
# 56  56     Staten Island  503          96796.0
# 57  57     Manhattan      101          144878.0
# 58  58     Manhattan      106          112383.0
#
#                                                                                                                                                                                                                                                                             neighborhoods
# 54  Arrochar, Bloomfield, Bulls Head, Chelsea, Concord, Dongan Hills, Egbertville, Emerson Hill, Grant City, Grasmere, Heartland Village, Lighthouse Hill, Manor Heights, Midland Beach, New Dorp, New Dorp Beach, New Springville, Old Town, South Beach, Todt Hill, Travis, Willowbrook
# 55  Bergen Beach, Canarsie, Flatlands, Georgetown, Marine Park, Mill Basin, Mill Island, Paerdegat Basin
# 56  Annadale, Arden Heights, Bay Terrace, Butler Manor, Charleston, Eltingville, Fresh Kills, Great Kills, Greenridge, Huguenot, Oakwood, Oakwood Beach, Oakwood Heights, Pleasant Plains, Prince's Bay, Richmond Town, Richmond Valley, Rossville, Sandy Ground, Tottenville, Woodrow
# 57  Battery Park City, Civic Center, Ellis Island, Governors Island, Liberty Island, South Street Seaport, Tribeca, Wall Street, World Trade Center
# 58  Beekman Place, Gramercy Park, Murray Hill, Peter Cooper Village, Stuyvesant Town, Sutton Place, Tudor City, Turtle Bay

# %% [markdown]
# ## Monthly tonnage from NYC Open Data
# - data is by community district
# - dates back consistently to 2004-ish, but we're focusing on the last decade
# - not using 2019 because the year isn't over!

# %%
df = pd.read_csv('src/data/monthly_tonnage.csv', na_values='NaN')
df = df.fillna(0)
## make datetime, separate the year
df.MONTH = pd.to_datetime(df.MONTH)
df['year'] = df.MONTH.astype(str).str.extract(r'^(.*)-.*-.*').astype(int)
df.BOROUGH_ID = df.BOROUGH_ID.astype(str)

df = df[df.year > 2008] ## just for the past 10 years

## some math to get the percents and totals
df['total_recycled'] = df.PAPERTONSCOLLECTED + df.MGPTONSCOLLECTED + df.RESORGANICSTONS
df['total_waste'] = df.total_recycled + df.REFUSETONSCOLLECTED
df['percent_recycled'] = df['total_recycled'] / df['total_waste'] * 100

# give the borough code
def get_boro_code(x):
    return x.BOROUGH_ID + "{:02d}".format(x.COMMUNITYDISTRICT)
df['borough_code'] = df.apply(get_boro_code, axis=1)

bydist_2018 = df[df['year']==2018].groupby('borough_code').percent_recycled.mean().reset_index()
bydist_2009 = df[df['year']==2009].groupby('borough_code').percent_recycled.mean().reset_index()

bydist = pd.merge(bydist_2018,bydist_2009['percent_recycled'],left_index=True,right_index=True)
bydist.columns = ['borough_code','pct_recyc_2018','pct_recyc_2009']
bydist['pct_change'] = (bydist['pct_recyc_2018'] / bydist['pct_recyc_2009'] - 1) * 100



bydist['pct_point_change'] = bydist['pct_recyc_2018'] - bydist['pct_recyc_2009']

demo_df = pd.read_csv('src/data/Bronx-2-indicators.csv')
demo_df.borocd = demo_df.borocd.astype(str)

merged = bydist.merge(demo_df, left_on='borough_code', right_on='borocd')
merged.to_csv('src/data/demographics_and_recyc.csv', index=False)

# %%
merged.sort_values('pct_change')
# Out:
#
# 37  Parks
# 49  Parks
# 51  Quality of life issues (noise, graffiti, petty crime, etc.)
# 6   Affordable housing
# 33  Neighborhood preservation (development trends)
# 29  Not submitted
# 53  Schools
# 46  Emergency response
# 25  Affordable housing
# 24  Affordable housing
# 48  Street conditions (roadway maintenance)
# 30  Affordable housing
# 56  Traffic
# 55  Resiliency
# 43  Affordable housing
# 45  Neighborhood preservation (development trends)
# 22  Not submitted
# 42  Affordable housing
# 52  Parks
# 36  Resiliency
# 11  Affordable housing
# 16  Schools
# 39  Affordable housing
# 19  Affordable housing
# 32  Affordable housing
# 31  Affordable housing
# 21  Quality of life issues (noise, graffiti, petty crime, etc.)
# 54  Commercial development (retail mix, small business and MWBE support, etc.)
# 10  Affordable housing
# 20  Affordable housing
# 18  Affordable housing
# 50  Affordable housing
# 8   Affordable housing
# 23  Parks
# 17  Crime
# 26  Affordable housing
# 27  Affordable housing
# 9   Affordable housing
# 12  Affordable housing
# 13  Health care services
# 15  Affordable housing
# 14  Health care services
#
#                                                                    son_issue_2  \
# 0   Traffic
# 5   Parks
# 58  Street flooding
# 41  Resiliency
# 57  Traffic
# 3   Neighborhood preservation (development trends)
# 4   Social services (including services for the homeless)
# 34  Street conditions (roadway maintenance)
# 28  Cultural facilities & programs
# 2   Senior services
# 35  Traffic
# 44  Schools
# 47  Senior services
# 38  Transit (buses & subways)
# 40  Schools
# 7   Parks
# 1   Parks
# 37  Street conditions (roadway maintenance)
# 49  Street conditions (roadway maintenance)
# 51  Resiliency
# 6   Schools
# 33  Parks
# 29  Not submitted
# 53  Senior services
# 46  Street flooding
# 25  Schools
# 24  Neighborhood preservation (development trends)
# 48  Street flooding
# 30  Schools
# 56  Transit (buses & subways)
# 55  Transit (buses & subways)
# 43  Health care services
# 45  Schools
# 22  Not submitted
# 42  Police-community relations
# 52  Quality of life issues (noise, graffiti, petty crime, etc.)
# 36  Street conditions (roadway maintenance)
# 11  Neighborhood preservation (development trends)
# 16  Traffic
# 39  Health care services
# 19  Parks
# 32  Schools
# 31  Neighborhood preservation (development trends)
# 21  Traffic
# 54  Neighborhood preservation (development trends)
# 10  Neighborhood preservation (development trends)
# 20  Crime
# 18  Neighborhood preservation (development trends)
# 50  Schools
# 8   Crime
# 23  Quality of life issues (noise, graffiti, petty crime, etc.)
# 17  Schools
# 26  Schools
# 27  Health care services
# 9   Commercial development (retail mix, small business and MWBE support, etc.)
# 12  Health care services
# 13  Parks
# 15  Crime
# 14  Unemployment
#
#                                                     son_issue_3  \
# 0   Other
# 5   Senior services
# 58  Traffic
# 41  Street conditions (roadway maintenance)
# 57  Other
# 3   Traffic
# 4   Transit (buses & subways)
# 34  Trash removal & cleanliness
# 28  Unemployment
# 2   Other
# 35  Trash removal & cleanliness
# 44  Senior services
# 47  Transit (buses & subways)
# 38  Trash removal & cleanliness
# 40  Senior services
# 7   Schools
# 1   Schools
# 37  Traffic
# 49  Street flooding
# 51  Street conditions (roadway maintenance)
# 6   Social services (including services for the homeless)
# 33  Quality of life issues (noise, graffiti, petty crime, etc.)
# 29  Not submitted
# 53  Street flooding
# 46  Traffic
# 25  Other
# 24  Senior services
# 48  Traffic
# 30  Other
# 56  Other
# 55  Unemployment
# 43  Schools
# 45  Traffic
# 22  Not submitted
# 42  Other
# 52  Street conditions (roadway maintenance)
# 36  Traffic
# 11  Schools
# 16  Transit (buses & subways)
# 39  Youth and children’s services
# 19  Senior services
# 32  Social services (including services for the homeless)
# 31  Police-community relations
# 21  Transit (buses & subways)
# 54  Traffic
# 10  Unemployment
# 20  Neighborhood preservation (development trends)
# 18  Schools
# 50  Senior services
# 8   Unemployment
# 23  Trash removal & cleanliness
# 17  Unemployment
# 26  Trash removal & cleanliness
# 27  Youth and children’s services
# 9   Trash removal & cleanliness
# 12  Unemployment
# 13  Schools
# 15  Youth and children’s services
# 14  Youth and children’s services
#
#    total_lot_area under18_rate under18_rate_boro under18_rate_nyc  \
# 0   36115322       12.8         14.5              21
# 5   25705923       8.7          14.5              21
# 58  476202613      21.5         22.1              21
# 41  203459457      22.9         23.1              21
# 57  457047905      21.1         22.1              21
# 3   38177268       8.2          14.5              21
# 4   28192622       8.2          14.5              21
# 34  69469761       20.9         23.1              21
# 28  113654190      25.9         23.1              21
# 2   33692052       11.7         14.5              21
# 35  66315554       36.3         23.1              21
# 44  53896836       22.1         20.2              21
# 47  53156349       17.7         20.2              21
# 38  91512013       22.1         23.1              21
# 40  61112422       21.8         23.1              21
# 7   37514104       14.8         14.5              21
# 1   25696432       12.8         14.5              21
# 37  55677503       25.3         23.1              21
# 49  142368027      20.6         20.2              21
# 51  120293776      20.9         20.2              21
# 6   64880905       15.1         14.5              21
# 33  87232868       19.6         23.1              21
# 29  64631699       21.0         23.1              21
# 53  182699928      22.8         20.2              21
# 46  159268879      21.3         20.2              21
# 25  54785585       17.7         23.1              21
# 24  93910079       21.1         23.1              21
# 48  302333666      17.5         20.2              21
# 30  80597297       23.9         23.1              21
# 56  312169271      23.5         22.1              21
# 55  204764322      27.4         20.2              21
# 43  85626722       16.5         20.2              21
# 45  42061791       22.2         20.2              21
# 22  62956349       22.3         25.2              21
# 42  100663156      14.6         20.2              21
# 52  180677413      18.6         20.2              21
# 36  73661971       19.8         23.1              21
# 11  60746542       17.4         14.5              21
# 16  24791621       28.7         25.2              21
# 39  34676362       26.1         23.1              21
# 19  77691993       21.3         25.2              21
# 32  30755404       21.7         23.1              21
# 31  30755039       19.4         23.1              21
# 21  136617274      19.0         25.2              21
# 54  239725268      19.9         20.2              21
# 10  55645510       20.6         14.5              21
# 20  83000712       24.3         25.2              21
# 18  32953274       26.6         25.2              21
# 50  70638805       22.1         20.2              21
# 8   24139761       15.4         14.5              21
# 23  103825695      22.4         25.2              21
# 17  35824799       28.9         25.2              21
# 26  54569653       25.7         23.1              21
# 27  40008621       21.0         23.1              21
# 9   26501338       20.3         14.5              21
# 12  41519289       28.4         25.2              21
# 13  51047521       28.4         25.2              21
# 15  36082878       27.5         25.2              21
# 14  31065067       28.9         25.2              21
#
#    unemployment_boro unemployment_cd  unemployment_nyc
# 0   4.2               2.8             4.9
# 5   4.2               2.4             4.9
# 58  3.2               3.2             4.9
# 41  5.1               4.9             4.9
# 57  3.2               3.2             4.9
# 3   4.2               3.7             4.9
# 4   4.2               3.7             4.9
# 34  5.1               4.4             4.9
# 28  5.1               5.1             4.9
# 2   4.2               4.1             4.9
# 35  5.1               3.5             4.9
# 44  4.4               3.7             4.9
# 47  4.4               3.1             4.9
# 38  5.1               4.1             4.9
# 40  5.1               4.9             4.9
# 7   4.2               2.1             4.9
# 1   4.2               2.8             4.9
# 37  5.1               4.9             4.9
# 49  4.4               5.3             4.9
# 51  4.4               5.7             4.9
# 6   4.2               3.4             4.9
# 33  5.1               4.5             4.9
# 29  5.1               4.0             4.9
# 53  4.4               7.1             4.9
# 46  4.4               3.8             4.9
# 25  5.1               5.1             4.9
# 24  5.1               4.1             4.9
# 48  4.4               2.8             4.9
# 30  5.1               4.5             4.9
# 56  3.2               3.3             4.9
# 55  4.4               5.1             4.9
# 43  4.4               3.2             4.9
# 45  4.4               3.6             4.9
# 22  6.9               6.7             4.9
# 42  4.4               5.0             4.9
# 52  4.4               3.2             4.9
# 36  5.1               5.4             4.9
# 11  4.2               6.8             4.9
# 16  6.9               7.7             4.9
# 39  5.1               8.3             4.9
# 19  6.9               5.6             4.9
# 32  5.1               6.6             4.9
# 31  5.1               5.1             4.9
# 21  6.9               4.9             4.9
# 54  4.4               5.0             4.9
# 10  4.2               6.2             4.9
# 20  6.9               7.2             4.9
# 18  6.9               8.6             4.9
# 50  4.4               4.7             4.9
# 8   4.2               4.1             4.9
# 23  6.9               7.1             4.9
# 17  6.9               8.2             4.9
# 26  5.1               6.8             4.9
# 27  5.1               7.2             4.9
# 9   4.2               6.9             4.9
# 12  6.9               5.9             4.9
# 13  6.9               5.9             4.9
# 15  6.9               6.6             4.9
# 14  6.9               8.2             4.9
#
# [59 rows x 189 columns]

# %%
demo_df[['borocd', 'fp_100_mhhi']].sort_values('fp_100_mhhi', ascending=False)
# Out:
#    borocd  fp_100_mhhi
# 0   101    121000.0
# 1   102    121000.0
# 25  302    119000.0
# 3   104    105000.0
# 43  402    101000.0
# 24  301    93000.0
# 5   106    92000.0
# 6   107    87000.0
# 7   108    72000.0
# 33  310    56000.0
# 48  407    54000.0
# 52  411    52000.0
# 42  401    51000.0
# 19  208    47000.0
# 22  211    44000.0
# 58  503    44000.0
# 21  210    42000.0
# 54  413    40000.0
# 6   107          39.911385       34.453511       0.158413    5.457874
# 18  207          18.936791       13.352245       0.418248    5.584546
# 15  204          14.073490       8.374256        0.680566    5.699234
# 26  303          17.377038       11.569885       0.501920    5.807153
# 43  402          30.037464       24.137940       0.244409    5.899525
# 42  401          30.828178       24.422432       0.262289    6.405746
# 14  203          15.030766       8.390757        0.791348    6.640009
# 13  202          16.516256       9.758206        0.692550    6.758049
# 9   110          18.616224       11.693098       0.592069    6.923126
# 25  302          39.969494       32.786442       0.219086    7.183052
# 27  304          20.133615       12.683127       0.587433    7.450488
# 8   109          24.624854       16.952862       0.452548    7.671992
# 54  413          30.332261       22.263200       0.362439    8.069062
# 19  208          31.783638       23.711502       0.340431    8.072136
# 21  210          32.927454       24.177927       0.361881    8.749527
# 29  306          52.022855       43.255251       0.202695    8.767604
# 52  411          38.831418       30.059758       0.291807    8.771660
# 50  409          30.236770       20.729975       0.458601    9.506795
# 23  212          30.887640       20.540474       0.503745    10.347166

# %%
bydist[bydist.borough_code.str.contains(r'5..') == True]
# Out:
#    borough_code  pct_recyc_2018  pct_recyc_2009  pct_change  pct_point_change
# 56  501          0.288775        0.235038        22.863147   0.053737
# 57  502          0.256751        0.261265       -1.727573   -0.004514
# 58  503          0.260752        0.273779       -4.758331   -0.013027

# %%
print('total refuse collected')
print(df[df.year == 2009].REFUSETONSCOLLECTED.sum())
print(df[df.year == 2018].REFUSETONSCOLLECTED.sum())
print('\n')

print('total recycle collected')
print(df[df.year == 2009].total_recycled.sum())
print(df[df.year == 2018].total_recycled.sum())
# Out:
# total refuse collected
# 2591531.2
# 2528028.2
#
#
# total recycle collected
# 542333.3999999999
# 593412.0

# %%
df.keys()
# Out:
# Index(['MONTH', 'BOROUGH', 'COMMUNITYDISTRICT', 'REFUSETONSCOLLECTED',
#        'PAPERTONSCOLLECTED', 'MGPTONSCOLLECTED', 'RESORGANICSTONS',
#        'SCHOOLORGANICTONS', 'LEAVESORGANICTONS', 'XMASTREETONS', 'BOROUGH_ID',
#        'year', 'total_recycled', 'percent_recycled', 'borough_code'],
#       dtype='object')

# %%
print('The 2009 waste outputs were')
print(df[df.year == 2009].groupby('BOROUGH').REFUSETONSCOLLECTED.sum())

print('\n')

print('The 2018 waste outputs were')
print(df[df.year == 2018].groupby('BOROUGH').REFUSETONSCOLLECTED.sum())
# Out:
# The 2009 waste outputs were
# BOROUGH
# Bronx            437885.5
# Brooklyn         802636.9
# Manhattan        444044.4
# Queens           719429.3
# Staten Island    187535.1
# Name: REFUSETONSCOLLECTED, dtype: float64
#
#
# The 2018 waste outputs were
# BOROUGH
# Bronx            410308.5
# Brooklyn         815628.8
# Manhattan        422740.9
# Queens           697380.6
# Staten Island    181969.4
# Name: REFUSETONSCOLLECTED, dtype: float64

# %%
print('The 2009 recycling outputs were')
print(df[df.year == 2009].groupby('BOROUGH').total_recycled.sum())

print('\n')

print('The 2018 recycling outputs were')
print(df[df.year == 2018].groupby('BOROUGH').total_recycled.sum())
# Out:
# The 2009 recycling outputs were
# BOROUGH
# Bronx            61685.4
# Brooklyn         156004.1
# Manhattan        122488.4
# Queens           154652.8
# Staten Island    47502.7
# Name: total_recycled, dtype: float64
#
#
# The 2018 recycling outputs were
# BOROUGH
# Bronx            76625.1
# Brooklyn         174584.6
# Manhattan        129404.5
# Queens           166399.4
# Staten Island    46398.4
# Name: total_recycled, dtype: float64

# %%
## a preview of our data
df.head(3)
# Out:
#         MONTH    BOROUGH  COMMUNITYDISTRICT  REFUSETONSCOLLECTED  \
# 3  2012-03-01  Manhattan  1                  1194.4
# 9  2012-01-01  Brooklyn   7                  3156.7
# 13 2016-11-01  Brooklyn   7                  3356.9
#
#     PAPERTONSCOLLECTED  MGPTONSCOLLECTED  RESORGANICSTONS  SCHOOLORGANICTONS  \
# 3   341.6               210.8            NaN              NaN
# 9   436.6               343.4            NaN              NaN
# 13  424.4               380.3             120.1           NaN
#
#     LEAVESORGANICTONS  XMASTREETONS BOROUGH_ID  year  total_recycled  \
# 3  NaN                NaN            1          2012  552.4
# 9  NaN                 20.1          3          2012  780.0
# 13  2.5               NaN            3          2016  804.7
#
#     percent_recycled borough_code
# 3   0.462492          101
# 9   0.247093          307
# 13  0.239715          307

# %% [markdown]
# ## The hierarchy of boroughs that recycle the most of their waste hasn't changed

# %%
recycled_2018_df = df[df.year == 2018].groupby('BOROUGH').percent_recycled.mean().reset_index()
recycled_2009_df = df[df.year == 2009].groupby('BOROUGH').percent_recycled.mean().reset_index()

print('Boroughs that recycled the highest percentage of their waste from 2018')
print(recycled_2018_df.sort_values('percent_recycled', ascending=False))
print('\n')
print('Boroughs that recycled the highest percentage of their waste from 2009')
print(recycled_2009_df.sort_values('percent_recycled', ascending=False))
# Out:
# Boroughs that recycled the highest percentage of their waste from 2018
#          BOROUGH  percent_recycled
# 2  Manhattan      0.310225
# 4  Staten Island  0.256344
# 3  Queens         0.244487
# 1  Brooklyn       0.224451
# 0  Bronx          0.187468
#
#
# Boroughs that recycled the highest percentage of their waste from 2009
#          BOROUGH  percent_recycled
# 2  Manhattan      0.288883
# 4  Staten Island  0.256694
# 3  Queens         0.220350
# 1  Brooklyn       0.200168
# 0  Bronx          0.140134

# %% [markdown]
# ### Some math to calculate changes over time

# %%
bydist_2018 = df[df['year']==2018].groupby('borough_code').percent_recycled.mean().reset_index()
bydist_2009 = df[df['year']==2009].groupby('borough_code').percent_recycled.mean().reset_index()

bydist = pd.merge(bydist_2018,bydist_2009['percent_recycled'],left_index=True,right_index=True)
bydist.columns = ['borough_code','pct_recyc_2018','pct_recyc_2009']
bydist['pct_change'] = bydist['pct_recyc_2018'] / bydist['pct_recyc_2009'] - 1
bydist['pct_point_change'] = bydist['pct_recyc_2018'] - bydist['pct_recyc_2009']
bydist.to_csv('10-year-change.csv', index=False)

# %% [markdown]
# ## But when checking out changes over the decades by individual districts, the Bronx leads the way

# %%
print('The community districts with the greatest percentage point increases are mostly in the Bronx (2**)')
bydist.sort_values('pct_change', ascending=False).head()
# Out:
# The community districts with the greatest percentage point increases are mostly in the Bronx (2**)
#    borough_code  pct_recyc_2018  pct_recyc_2009  pct_change  pct_point_change
# 14  203          0.150308        0.083908        0.791348    0.066400
# 13  202          0.165163        0.097582        0.692550    0.067580
# 15  204          0.138580        0.083743        0.654833    0.054837
# 9   110          0.186162        0.116931        0.592069    0.069231
# 27  304          0.201336        0.126831        0.587433    0.074505

# %%
print('The community districts with the lowest percentage point decreases are mostly in Mahattan (1**), Brooklyn (3**) and Staten Island (5**)')
bydist.sort_values('pct_change', ascending=True).head()
# Out:
# The community districts with the lowest percentage point decreases are mostly in Mahattan (1**), Brooklyn (3**) and Staten Island (5**)
#    borough_code  pct_recyc_2018  pct_recyc_2009  pct_change  pct_point_change
# 0   101          0.457068        0.525482       -0.130192   -0.068414
# 5   106          0.341653        0.390732       -0.125609   -0.049079
# 58  503          0.260752        0.273779       -0.047583   -0.013027
# 34  311          0.228816        0.237253       -0.035561   -0.008437
# 41  318          0.211713        0.218775       -0.032279   -0.007062

# %%
# opening the community-districts json from NYC Open Data
with open('src/data/community-districts.json') as f:
    data = json.load(f)

# %% [markdown]
# ### One Dataset to Rule Them All
#
# It has demographic data from NYC Open Data (originally pulled from the Census), the Monthly Tonnage Data, and the math we did to calculate change over time

# %% [markdown]
# ### The districts with the highest poverty rate have among the highest percentage increase in recycling in the last decade
#
# The Bronx takes up 6 of the 10 districts with the greatest increase, with each of the 6 districts having a higher poverty rate than the others

# %%
df = pd.read_csv('src/data/joined_and_tonnage.csv')
df = df[df.year == 2018].groupby('boro_cd')
poverty_df = df['pct_change'].median().reset_index().merge(df['poverty_rate'].median().reset_index(), on='boro_cd')
poverty_df = poverty_df.merge(df.fp_100_mhhi.median().reset_index(), on='boro_cd').rename(columns={'fp_100_mhhi':'median_household_income'})
poverty_df = poverty_df.merge(df.pct_recyc_2018.mean().reset_index(), on='boro_cd')
poverty_df = poverty_df.merge(df.pct_recyc_2009.mean().reset_index()  , on='boro_cd')
poverty_df['pct_pt_change'] = (poverty_df.pct_recyc_2018 - poverty_df.pct_recyc_2009) * 100
poverty_df['pct_change'] = poverty_df['pct_change'] * 100

# %%
pos = poverty_df[(poverty_df.pct_pt_change > 0)].sort_values('pct_pt_change', ascending=True)

print('The median poverty rate of the top 50 districts with a positive
 recycling percentage point increase is ' + pos.sort_values('pct_pt_change', ascending=False).poverty_rate.median().astype(str) + '% and the median household income is $'+pos.sort_values('pct_pt_change', ascending=False).median_household_income.median().astype(str))

# poverty_df[['boro_cd', 'poverty_rate', 'pct_pt_change', 'pct_change', 'median_household_income']].sort_values('pct_pt_change', ascending=False).head(10)


pos[['boro_cd', 'poverty_rate', 'median_household_income', 'pct_pt_change']].sort_values('pct_pt_change', ascending=False)
# Out:
# The median poverty rate of the top 10 districts with the greatest recycling percentage point increase is 20.65% and the median household income is $32000.0
#     boro_cd  poverty_rate  median_household_income  pct_pt_change
# 27  304      24.8         NaN                       7.450488
# 9   110      20.2          25000.0                  6.923126
# 8   109      20.7          32000.0                  6.871353
# 13  202      31.0          17000.0                  6.758049
# 14  203      30.3          31000.0                  6.640009
# 42  401      18.1          51000.0                  6.405746
# 26  303      21.2         NaN                       5.807153
# 18  207      27.4         NaN                       5.584546
# 19  208      15.8          47000.0                  5.540257
# 15  204      32.4          24000.0                  5.483737
# 31  308      20.4         NaN                       5.203067
# 6   107      9.2           87000.0                  4.970080
# 12  201      31.0          17000.0                  4.816070
# 1   102      8.8           121000.0                 4.735485
# 10  111      22.3          22000.0                  4.574745
# 23  212      20.9          29000.0                  4.553335
# 17  206      30.3          31000.0                  4.528750
# 21  210      14.0          42000.0                  4.420331
# 25  302      11.0          119000.0                 4.256700
# 29  306      9.6           37000.0                  4.117963
# 50  409      21.5         NaN                       4.111355
# 11  112      19.6          22000.0                  3.977274
# 20  209      27.6          36000.0                  3.899700
# 32  309      20.8         NaN                       3.867813
# 45  404      25.6         NaN                       3.523532
# 7   108      7.2           72000.0                  3.481372
# 43  402      18.8          101000.0                 3.333318
# 36  313      24.4          15000.0                  3.273246
# 16  205      35.6          16000.0                  3.132685
# 52  411      14.1          52000.0                  2.976452
# 53  412      19.0          26000.0                  2.745297
# 54  413      12.3          40000.0                  2.630041
# 24  301      15.5          93000.0                  2.528458
# 30  307      27.9          25000.0                  2.130237
# 33  310      19.0          56000.0                  1.924402
# 46  405      16.8         NaN                       1.855389
# 37  314      21.5         NaN                       1.849538
# 56  501      21.2          27000.0                  1.652458
# 47  406      15.1         NaN                       1.643174
# 39  316      29.4         NaN                       1.608085
# 22  211      20.6          44000.0                  1.443540
# 4   105      11.3         NaN                       1.207248
# 48  407      25.5          54000.0                  1.196146
# 40  317      19.5         NaN                       1.100469
# 2   103      19.3          18000.0                  1.080851
# 51  410      17.3          38000.0                  1.073836
# 55  414      17.2          29000.0                  0.961786
# 44  403      24.0         NaN                       0.897682
# 28  305      28.7          20000.0                  0.584582
# 49  408      20.8         NaN                       0.437343

# %% [markdown]
# ### Districts with the greatest decrease have a lower poverty rate

# %%
neg = poverty_df[(poverty_df.pct_pt_change < 0)].sort_values('pct_pt_change', ascending=True)

print('The median poverty rate of the 9 districts with a negative recycling percentage point decrease is ' + neg.poverty_rate.median().astype(str) + '% and the median household income is $'+neg.median_household_income.median().astype(str))

print("\nOnly these 9 districts had a decrease in their recycling")

neg[['boro_cd', 'poverty_rate', 'median_household_income', 'pct_pt_change']]
# Out:
# The median poverty rate of the 9 districts with a negative recycling percentage point decrease is 14.6% and the median household income is $41500.0
#
# Only these 9 districts had a decrease in their recycling
#     boro_cd  poverty_rate  median_household_income  pct_pt_change
# 0   101      8.8           121000.0                -6.841355
# 5   106      9.8           92000.0                 -4.907941
# 58  503      12.3          44000.0                 -1.302732
# 34  311      22.5          35000.0                 -0.843702
# 41  318      14.6          36000.0                 -0.706172
# 3   104      11.3          105000.0                -0.461614
# 57  502      14.9          37000.0                 -0.454724
# 38  315      18.6          39000.0                 -0.410527
# 35  312      27.2         NaN                      -0.033087

# %%
print("Districts with a poverty rate above 25 percent have an average increase of " + (poverty_df[poverty_df.poverty_rate > 25]['pct_pt_change'].median()).astype(str) + '%')

print("\nDistricts with a poverty rate below 10 percent have an average increase of " + (poverty_df[poverty_df.poverty_rate < 15]['pct_pt_change'].median()).astype(str) + '%')
# Out:
# Districts with a poverty rate above 25 percent have an average increase of 3.7116161000000005%
#
# Districts with a poverty rate below 10 percent have an average increase of 2.630041300000005%

# %%
model = smf.ols(formula='pct_change ~ median_household_income', data=poverty_df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             pct_change   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     8.131
# Date:                Thu, 05 Dec 2019   Prob (F-statistic):            0.00678
# Time:                        20:22:29   Log-Likelihood:                -189.22
# No. Observations:                  43   AIC:                             382.4
# Df Residuals:                      41   BIC:                             386.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  31.9103      5.660      5.638      0.000      20.480      43.341
# median_household_income    -0.0003      0.000     -2.852      0.007      -0.000   -8.39e-05
# ==============================================================================
# Omnibus:                        6.637   Durbin-Watson:                   0.822
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                5.863
# Skew:                           0.896   Prob(JB):                       0.0533
# Kurtosis:                       3.251   Cond. No.                     1.03e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
joined = pd.read_csv('src/data/joined_and_tonnage.csv')
joined['point_change'] = joined['pct_recyc_2018'] - joined['pct_recyc_2009']

# %%
# What effect does the number of coffees sold have on our revenue?
model = smf.ols(formula='REFUSETONSCOLLECTED ~ fp_100_mhhi', data=joined)
results = model.fit()

results.summary()

# %%
# %matplotlib inline

import seaborn as sns

sns.regplot(x='poverty_rate', y='pct_change', ci=None, data=joined, color='lightblue')

# %% [markdown]
# <hr>

# %% [markdown]
# ## 311 data regarding missed recyling collections
#
# Data is <code>311_Service_Requests_from_2010_to_Present.csv</code>
#
# I grabbed and filtered the data on NYC Open Data and filtered it to only include DSNY complaints mentioning recycling

# %%
df_311 = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv', usecols=['Unique Key', 'Created Date', 'Agency', 'Agency Name', 'Complaint Type', 'Descriptor','Location Type', 'Incident Zip', 'Incident Address', 'Street Name', 'City', 'Resolution Description', 'Community Board', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Latitude', 'Longitude', 'Borough'])
df_311['year'] = df_311['Created Date'].str.extract('\d+\/\d+\/(\d+)') ## this grabs the year

# %%
df_311.head(1)
# Out:
#    Unique Key            Created Date Agency        Agency Name  \
# 0    44916024  11/13/2019 10:19:00 AM   DSNY  BCC - Queens West
#
#                       Complaint Type                         Descriptor  \
# 0  Missed Collection (All Materials)  1R Missed Recycling-All Materials
#
#   Location Type  Incident Zip Incident Address Street Name     City  \
# 0      Sidewalk       11378.0    59-15 69 LANE     69 LANE  Maspeth
#
#                               Resolution Description Community Board Borough  \
# 0  The Department of Sanitation is in the process...       05 QUEENS  QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane)   Latitude  \
# 0                   1014336.0                    203004.0  40.723825
#
#    Longitude  year
# 0 -73.891457  2019

# %%
df_311.year.value_counts().reset_index().sort_values('index', ascending=True).plot(kind='bar', x='index', y='year', legend=False)

# %%
df_311['Community Board'].value_counts().head(10)
# Out:
# 01 STATEN ISLAND    14443
# 03 STATEN ISLAND    13643
# 02 STATEN ISLAND     9859
# 01 BROOKLYN          5280
# 07 QUEENS            4791
# 12 BROOKLYN          3307
# 13 QUEENS            3241
# 03 BROOKLYN          2706
# 08 QUEENS            2661
# 12 QUEENS            2604
# Name: Community Board, dtype: int64

# %%
df_311['Borough'].value_counts().head(6)
# Out:
# STATEN ISLAND    37952
# BROOKLYN         32470
# QUEENS           27294
# MANHATTAN         8435
# BRONX             6690
# Unspecified          8
# Name: Borough, dtype: int64

# %% [markdown]
# #Different Drop off locations

# %%
textile=pd.read_csv('Textile_Drop-Off_Locations_in_NYC.csv')
textile
# Out:
#                        Address         BBL      BIN  BoroCD        Borough  \
# 0                  606 E 89 St  3079930000  3224082     318       Brooklyn
# 1               1133 Ogden Ave  2025260000  2088158     204          Bronx
# 2                 10 Cebra Ave  5001150000  5002741     501  Staten Island
# 3                  1169 Bay St  5028290000  5107418     501  Staten Island
# 4     137-42 Guy R Brewer Blvd  4123090000  4266757     412         Queens
# ...                        ...         ...      ...     ...            ...
# 1136               70-21 73 Pl  4037920000  4092075     405         Queens
# 1137         321 E Tremont Ave  2028140000  2007764     205          Bronx
# 1138           121-02 Irwin Pl  4124800000  4269730     412         Queens
# 1139             125 Kings Hwy  3066180000  3175252     311       Brooklyn
# 1140         1003 Clarkson Ave  3046270000  3100476     317       Brooklyn
#
#       CT2010  CouncilDistrict  \
# 0        964               46
# 1        199               16
# 2         75               49
# 3          6               49
# 4        294               28
# ...      ...              ...
# 1136   63301               30
# 1137     381               15
# 1138     368               27
# 1139     428               44
# 1140     882               41
#
#                                          Items_Accepted  Latitude  Longitude  \
# 0     Clothing, Shoes, Accessories, Coats, Bedding A...  40.64240  -73.90993
# 1                                       Clothing, Shoes  40.83659  -73.92780
# 2                                       Clothing, Shoes  40.63412  -74.08648
# 3                          Clothing, Shoes, Accessories  40.61481  -74.06644
# 4     Clothing, Shoes, Accessories, Bedding and line...  40.67093  -73.77412
# ...                                                 ...       ...        ...
# 1136  Clothing, Shoes, Coats, Accessories, Bedding, ...  40.70602  -73.87672
# 1137         Clothing, Shoes, Coats, Bedding And Linens  40.84892  -73.90240
# 1138  Clothing, Shoes, Accessories, Bedding and line...  40.68420  -73.76946
# 1139  Clothing, Shoes, Coats, Accessories, Bedding, ...  40.60628  -73.98666
# 1140  Clothing, Shoes, Accessories, Bedding and line...  40.65844  -73.92474
#
#       ... Unit                           Vendor_Name  \
# 0     ...  NaN          Christian Church Of Canarsie
# 1     ...  NaN                           Usagain LLC
# 2     ...  NaN                            Planet Aid
# 3     ...  NaN               Community Recycling LLC
# 4     ...  NaN                                Helpsy
# ...   ...  ...                                   ...
# 1136  ...  NaN                       Spin Green, LLC
# 1137  ...  NaN                    NAICA East Tremont
# 1138  ...  NaN                                Helpsy
# 1139  ...  NaN  American Recycling Technologies Inc.
# 1140  ...  NaN                                Helpsy
#
#                                                 Website  \
# 0     https://www1.nyc.gov/assets/donate/giveandfind...
# 1                               http://www.usagain.com/
# 2                             http://www.planetaid.org/
# 3                   https://www.communityrecycling.biz/
# 4                                https://www.helpsy.co/
# ...                                                 ...
# 1136                          http://www.spingreen.com/
# 1137  https://www1.nyc.gov/assets/donate/giveandfind...
# 1138                             https://www.helpsy.co/
# 1139              http://www.americanrecyclingtech.com/
# 1140                             https://www.helpsy.co/
#
#                                       point zipcode Zip Codes  \
# 0              POINT (-73.909932 40.642403)   11236     13827
# 1              POINT (-73.927801 40.836595)   10452     10930
# 2      POINT (-74.086477 40.63412199999999)   10301     10369
# 3              POINT (-74.066443 40.614809)   10305     10692
# 4              POINT (-73.774124 40.670926)   11434     24669
# ...                                     ...     ...       ...
# 1136           POINT (-73.876725 40.706017)   11385     15310
# 1137   POINT (-73.902408 40.84892300000001)   10457     10935
# 1138  POINT (-73.769464 40.684194999999995)   11434     24669
# 1139           POINT (-73.986653 40.606276)   11223     18183
# 1140  POINT (-73.924742 40.658435999999995)   11212     17614
#
#      Community Districts Borough Boundaries City Council Districts  \
# 0                    5.0                2.0                    8.0
# 1                   50.0                5.0                   42.0
# 2                    4.0                1.0                   13.0
# 3                    4.0                1.0                   13.0
# 4                   41.0                3.0                   46.0
# ...                  ...                ...                    ...
# 1136                54.0                3.0                   34.0
# 1137                 6.0                5.0                   22.0
# 1138                41.0                3.0                    6.0
# 1139                 1.0                2.0                   18.0
# 1140                61.0                2.0                   17.0
#
#      Police Precincts
# 0                42.0
# 1                27.0
# 2                74.0
# 3                74.0
# 4                71.0
# ...               ...
# 1136             62.0
# 1137             29.0
# 1138             71.0
# 1139             37.0
# 1140             40.0
#
# [1141 rows x 28 columns]

# %%
bins=textile.BoroCD.value_counts().reset_index()
bins = bins.rename(columns={'index': 'BoroCD','BoroCD':'No.BoroCD'})
bins.head(3)
# Out:
#    BoroCD  No.BoroCD
# 0     501         59
# 1     412         57
# 2     318         43

# %%
borou=textile.Borough.value_counts().reset_index()
borou = borou.rename(columns={'index': 'Borough','Borough':'No_Borough'})
borou.head(5)
# Out:
#          Borough  No_Borough
# 0       Brooklyn         325
# 1         Queens         293
# 2      Manhattan         206
# 3          Bronx         205
# 4  Staten Island         112

# %%
prc=pd.read_csv('10-year-change.csv')
prc = prc.rename(columns={'borough_code': 'BoroCD'})
prc.head(5)
# Out:
#    BoroCD  pct_recyc_2018  pct_recyc_2009  pct_change
# 0     101        0.457068        0.525482   -0.130192
# 1     102        0.405030        0.357676    0.132396
# 2     103        0.220118        0.209310    0.051639
# 3     104        0.372049        0.376665   -0.012255
# 4     105        0.346514        0.334442    0.036097

# %%
join=bins.merge(prc, on='BoroCD')
join.head(5)
# Out:
#    BoroCD  No.BoroCD  pct_recyc_2018  pct_recyc_2009  pct_change
# 0     501         59        0.251563        0.235038    0.070306
# 1     412         57        0.193020        0.165567    0.165812
# 2     318         43        0.211713        0.218775   -0.032279
# 3     209         43        0.141494        0.102497    0.380468
# 4     305         41        0.141763        0.135917    0.043010

# %%
secondjoin=join.merge(borou,on)

# %%
join.to_csv('bin-and-pct.csv')

# %%
fig=join.plot(kind='scatter',x='No.BoroCD',y='pct_recyc_2018')
